# %%
import pandas as pd
path = r"H:\Python\3Etapa\AnaliseDados\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %% [markdown]
# Carregando o excell com tudo, sem nenhum tipo de alteração, o header serve apenas para cortar as 2 primeiras informações "inuteis"

# %%
dado_bruto = pd.read_excel(path, header = 2)
dado_bruto
# Out:
#       Unnamed: 0                                                 UF  COD. UF  \
# 0            NaN                                                 RO     11.0
# 1            NaN                                                 RO     11.0
# 2            NaN                                                 RO     11.0
# 3            NaN                                                 RO     11.0
# 4            NaN                                                 RO     11.0
# ...          ...                                                ...      ...
# 5569         NaN                                                 DF     53.0
# 5570         NaN                                                NaN      NaN
# 5571         NaN  Nota: Para o cálculo das taxas de crescimento ...      NaN
# 5572         NaN                                                NaN      NaN
# 5573         NaN  Fonte: IBGE. Diretoria de Pesquisas - DPE -  C...      NaN
#
# ...

# %%
dados_trabalhados = dado_bruto.iloc[0:5570,1:]

# %%
dados_trabalhados.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO',
#        'População Município 2010\n(Sinopse)',
#        'População 2010 (Alterações de Limites até 2022)1',
#        'População Censo 2022'],
#       dtype='str')

# %%
dados_trabalhados["Diferenca"] = (dados_trabalhados["População Censo 2022"]  - dados_trabalhados["População Município 2010\n(Sinopse)"])

# %%
dados_trabalhados
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  \
# 0     RO     11.0        15.0  Alta Floresta D'Oeste
# 1     RO     11.0        23.0              Ariquemes
# 2     RO     11.0        31.0                 Cabixi
# 3     RO     11.0        49.0                 Cacoal
# 4     RO     11.0        56.0             Cerejeiras
# ...   ..      ...         ...                    ...
# 5565  GO     52.0     22005.0             Vianópolis
# 5566  GO     52.0     22054.0         Vicentinópolis
# 5567  GO     52.0     22203.0               Vila Boa
# 5568  GO     52.0     22302.0          Vila Propício
# 5569  DF     53.0       108.0               Brasília
#
#       População Município 2010\n(Sinopse)  \
# 0                                 24392.0
# 1                                 90353.0
# 2                                  6313.0
# 3                                 78574.0
# 4                                 17029.0
# ...                                   ...
# ...

# %%
dados_trabalhados.to_csv("dados_trabalhados.csv", index=False, encoding="utf-8-sig")

# %%
dados_trabalhados = dados_trabalhados.sort_values(
    by="Diferenca",
    ascending=False
)
dados_trabalhados
# Out:
#       UF  COD. UF  COD. MUNIC NOME DO MUNICÍPIO  \
# 111   AM     13.0      2603.0            Manaus
# 5569  DF     53.0       108.0          Brasília
# 3829  SP     35.0     50308.0         São Paulo
# 3848  SP     35.0     52205.0          Sorocaba
# 5417  GO     52.0      8707.0           Goiânia
# ...   ..      ...         ...               ...
# 4931  RS     43.0     14902.0      Porto Alegre
# 169   PA     15.0      1402.0             Belém
# 3247  RJ     33.0      4904.0       São Gonçalo
# 3242  RJ     33.0      4557.0    Rio de Janeiro
# 2162  BA     29.0     27408.0          Salvador
#
#       População Município 2010\n(Sinopse)  \
# 111                             1802014.0
# 5569                            2570160.0
# 3829                           11253503.0
# 3848                             586625.0
# 5417                            1302001.0
# ...                                   ...
# 4931                            1409351.0
# ...

# %%
dados_trabalhados.to_csv("dados_trabalhados.csv", index=False, encoding="utf-8-sig")
